# %%
import nltk
import mysql.connector
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Users/premt/Downloads/shopping.csv')

# %%
# drop = df.drop_duplicates(inplace=True)
drop1 = df.dropna(inplace=True)
print(df)
# Out:
#                                                    name     brand  \
# 0     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...    Amazon
# 1           Amazon - Echo Plus w/ Built-In Hub - Silver    Amazon
# 2     Amazon Echo Show Alexa-enabled Bluetooth Speak...    Amazon
# 3     Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...    Amazon
# 4     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...    Amazon
# ...                                                 ...       ...
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Flipkart
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Flipkart
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Flipkart
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Flipkart
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Flipkart
#
#                                              categories  \
# 0     Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1     Amazon Echo,Smart Home,Networking,Home & Tools...
# ...

# %%
df.rename(columns = {'reviews.date':'reviews_date'},inplace=True)
df.rename(columns = {'reviews.text':'reviews_text'},inplace=True)
df.rename(columns = {'reviews.title':'reviews_title'},inplace=True)
d = df.drop_duplicates(inplace = True)
dd = df.dropna(inplace = True)

print(df)
# Out:
#                                                    name     brand  \
# 0     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...    Amazon
# 1           Amazon - Echo Plus w/ Built-In Hub - Silver    Amazon
# 2     Amazon Echo Show Alexa-enabled Bluetooth Speak...    Amazon
# 3     Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...    Amazon
# 4     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...    Amazon
# ...                                                 ...       ...
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Flipkart
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Flipkart
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Flipkart
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Flipkart
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Flipkart
#
#                                              categories  \
# 0     Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1     Amazon Echo,Smart Home,Networking,Home & Tools...
# ...

# %%
df['sentiment'] = ''
print(df)
# Out:
#                                                    name     brand  \
# 0     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...    Amazon
# 1           Amazon - Echo Plus w/ Built-In Hub - Silver    Amazon
# 2     Amazon Echo Show Alexa-enabled Bluetooth Speak...    Amazon
# 3     Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...    Amazon
# 4     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...    Amazon
# ...                                                 ...       ...
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Flipkart
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Flipkart
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Flipkart
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Flipkart
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Flipkart
#
#                                              categories  \
# 0     Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1     Amazon Echo,Smart Home,Networking,Home & Tools...
# ...
